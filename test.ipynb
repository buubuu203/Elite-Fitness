# %%
import pandas as pd

# %%
df = pd.read_csv('./dataset/velocities.csv')
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#     frameNo  leftArm  rightArm
# 0        10        0         3
# 1        20      -15        -9
# 2        30     -336      -195
# 3        40     -147      -300
# 4        50       -9        -6
# 5        60       -3         3
# 6        70        3         0
# 7        80       15        12
# 8        90      210       279
# 9       100      270       201
# 10      110       -3         3
# 11      120        6         0
# 12      130        3         3
# 13      140        3         3
# 14      150      -18        -6
# 15      160     -357      -381
# 16      170     -126      -114
# 17      180       -3         0
# 18      190        0         3
# 19      200       21         9
# 20      210      345       357
# 21      220      129       126
# 22      230        3         0
# 23      240        3         6

# %%
velocities = df.to_dict()
velocities
# Out:
# {'frameNo': {0: 10,
#   1: 20,
#   2: 30,
#   3: 40,
#   4: 50,
#   5: 60,
#   6: 70,
#   7: 80,
#   8: 90,
#   9: 100,
#   10: 110,
#   11: 120,
#   12: 130,
#   13: 140,
#   14: 150,
#   15: 160,
#   16: 170,
#   17: 180,
#   18: 190,
#   19: 200,
#   20: 210,
#   21: 220,
#   22: 230,
#   23: 240},
#  'leftArm': {0: 0,
#   1: -15,
#   2: -336,
#   3: -147,
#   4: -9,
#   5: -3,
#   6: 3,
#   7: 15,
#   8: 210,
#   9: 270,
#   10: -3,
#   11: 6,
#   12: 3,
#   13: 3,
#   14: -18,
#   15: -357,
#   16: -126,
#   17: -3,
#   18: 0,
#   19: 21,
#   20: 345,
#   21: 129,
#   22: 3,
#   23: 3},
#  'rightArm': {0: 3,
#   1: -9,
#   2: -195,
#   3: -300,
#   4: -6,
#   5: 3,
#   6: 0,
#   7: 12,
#   8: 279,
#   9: 201,
#   10: 3,
#   11: 0,
#   12: 3,
#   13: 3,
#   14: -6,
#   15: -381,
#   16: -114,
#   17: 0,
#   18: 3,
#   19: 9,
#   20: 357,
#   21: 126,
#   22: 0,
#   23: 6}}
